# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.ROOT)
from scipy.stats import norm
import random
import aghast
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size

# %%
def QuartzWindowCEDARHTransmittance(iWindow,Wavelength):
    x = Wavelength
    f = -999
    if(x < 218):
        return 0
    if(x > 700):
        x = 700
        
    iWindow += 1
    
    #print(iWindow)

    if(iWindow == 1):
        if(x >= 218 and x < 246):
            f = -4.11039779e-05 * pow(x, 3) + 2.86929772e-02 * pow(x, 2) + -6.64646618e+00 * x + 5.11186456e+02
    
        elif(x >= 246 and x < 295):
            f = 2.16681351e-06 * pow(x, 3) + -1.81862119e-03 * pow(x, 2) + 5.11346718e-01 * x + -4.73737467e+01
    
        elif(x >= 295 and x < 400):
            f = 8.43738855e-08 * pow(x, 3) + -9.49909704e-05 * pow(x, 2) + 3.59630121e-02 * x - 3.67506532e+00
    
        elif(x >= 400):
            f = -2.274769294566873e-10 * pow(x, 3) + 3.6319254670767923e-07 * pow(x, 2)+ -0.00013165099898537937 * x + 0.9221299285871312
    
    
    elif(iWindow == 2):
        if(x >= 218 and x < 246):
            f = -3.809435193594334e-05 * pow(x, 3) + 0.02668671852791952 * pow(x, 2) + -6.204074022979601 * x + 478.90810305848214
    
        elif(x >= 246 and x < 295):
            f = 2.3804438810233594e-06 * pow(x, 3) + -0.0019908839971722273 * pow(x, 2) + 0.5580549708678741 * x + -51.67585798284769

        elif(x >= 295 and x < 400):
            f = 9.423628212043439e-08 * pow(x, 3) + -0.00010522846641591158 * pow(x, 2) + 0.03960381808064974 * x + -4.139946820550639
    
        elif(x >= 400):
            f = 7.608954764150227e-11 * pow(x, 3) + -2.1708751926807533e-07 * pow(x, 2) + 0.00024143630452548747 * x + 0.8288143590890062
    
    
    elif(iWindow == 3):
        if(x >= 218 and x < 246):
            f = -4.069328496912898e-05 * pow(x, 3) + 0.028292809671339503 * pow(x, 2) + -6.525570292072722 * x + 499.5919906136786
    
        elif(x >= 246 and x < 295):
            f = 2.4302513889536216e-06 * pow(x, 3) + -0.0020445038036341263 * pow(x, 2) + 0.5753972506367294 * x + -53.335503221314696
    
        elif(x >= 295 and x < 400):
            f = 5.4720284121751934e-08 * pow(x, 3) + -6.23705802941529e-05 * pow(x, 2) + 0.023899000523567884 * x + -2.1535449437836705
    
        elif(x >= 400):
            f = -2.585477114727037e-10 * pow(x, 3) + 5.634304819624665e-07 * pow(x, 2) + -0.0003721156186314771 * x + 1.0047948358674903
    
    
    elif(iWindow == 4):
        if(x >= 218 and x < 246):
            f = -3.9805092701628935e-05 * pow(x, 3) + 0.0276399718320393 * pow(x, 2) + -6.366615630899579 * x + 486.76440070327584

        elif(x >= 246 and x < 295):
            f = 2.607804718903866e-06 * pow(x, 3) + -0.002179702907292894 * pow(x, 2) + 0.6091310433266354 * x + -56.104031788219416
    
        elif(x >= 295 and x < 400):
            f = 5.394902648645878e-08 * pow(x, 3) + -5.974478622231392e-05 * pow(x, 2) + 0.02238637937967184 * x + -1.9401420527649282
    
        elif(x >= 400):
            f = -1.3424815024391928e-10 * pow(x, 3) + 2.8328557253805954e-07 * pow(x, 2) + -0.00014759288847822986 * x + 0.9296519676340556
    
    
    elif(iWindow == 5):
        if(x >= 218 and x < 246):
            f = -4.026044807217661e-05 * pow(x, 3) + 0.028125087268148063 * pow(x, 2) + -6.519851609425991 * x + 501.83282403472884
    
        elif(x >= 246 and x < 295):
            f = 2.2998584298082745e-06 * pow(x, 3) + -0.0019281932769371166 * pow(x, 2) + 0.5416658346847079 * x + -50.19632882594679
    
        elif(x >= 295 and x < 400):
            f = 8.116988471060152e-08 * pow(x, 3) + -9.07196710390931e-05 * pow(x, 2) + 0.03412930128016914 * x + -3.4208602086264928
    
        elif(x >= 400):
            f = -2.6893392890493907e-10 * pow(x, 3) + 5.13205980921548e-07 * pow(x, 2) + -0.00026751528092079614 * x + 0.9530332732775446
    
    
    elif(iWindow == 6):
        if(x >= 218 and x < 246):
            f = -3.1223931316470255e-05 * pow(x, 3) + 0.021725868519426587 * pow(x, 2) + -5.013593174756257 * x + 383.96044849868076
    
        elif(x >= 246 and x < 295):
            f = 9.482373230648229e-07 * pow(x, 3) + -0.0008334196897081745 * pow(x, 2) + 0.24756877704241154 * x + -24.0374603259202
    
        elif(x >= 295 and x < 400):
            f = 8.233301744707107e-08 * pow(x, 3) + -9.547507479847616e-05 * pow(x, 2) + 0.03730903576361997 * x + -4.001761422102015
    
        elif(x >= 400):
            f = -1.904338123217788e-11 * pow(x, 3) + 8.409502647180658e-08 * pow(x, 2) + -3.142433346301535e-05 * x + 0.9167920493061781
    
    
    elif(iWindow == 7):
        if(x >= 218 and x < 246):
            f = -2.230030342970399e-05 * pow(x, 3) + 0.015758350387650513 * pow(x, 2)  + -3.6919233798262407 * x + 286.9850887177151
    
        elif(x >= 246 and x < 295):
            f = 8.092332381485389e-07 * pow(x, 3) + -0.0007049118121416209 * pow(x, 2) + 0.21032333990143628 * x + -20.715816098932855
    
        elif(x >= 295 and x < 400):
            f = 1.421072371469425e-07 * pow(x, 3) + -0.00016431097943130294 * pow(x, 2) + 0.06387164658393837 * x + -7.432497926036235
    
        elif(x >= 400):
            f = -6.0609476804551776e-12 * pow(x, 3) + 6.973713082744009e-08 * pow(x, 2) + -3.277227443220169e-05 * x + 0.9234629146656347
    
    
    elif(iWindow == 8):
        if(x >= 218 and x < 246):
            f = -3.845369558874715e-05 * pow(x, 3) + 0.026718480620871746 * pow(x, 2) + -6.157507418160105 * x + 470.97393467081884
    
        elif(x >= 246 and x < 295):
            f = 2.3730263844012878e-06 * pow(x, 3) + -0.001990596260159832 * pow(x, 2) + 0.5589009348299779 * x + -51.69416071431379
    
        elif(x >= 295 and x < 400):
            f = 7.207227590276765e-08 * pow(x, 3) + -7.976339347725213e-05 * pow(x, 2) + 0.029690116647956177 * x + -2.796019060080562
    
        elif(x >= 400):
            f = -1.0411189727864261e-10 * pow(x, 3) + 2.500134423383643e-07 * pow(x, 2) + -0.00017823574678597754 * x + 0.9676533585243703
    
    
    if(f < 0):
        return 0

    if(f > 0.999):
        f = 0.999

    return f

def ELConvert(value):
  return  1.239841 / value

# %%
def Gaus(x,mean,sigma,norm=False):
        if (sigma == 0): return 1.e30
        arg = (x-mean)/sigma
        res = np.exp(-0.5*arg*arg)
        if not norm: return res
        return res/(np.sqrt(2*np.pi)*sigma)

def CedarQE_R9880U_110(wavelength):
        par = [1489.053765000671,     -20.61340505642701,     0.09607362916193821,
                      -0.000144918944048782, -1.087924475686453e-07, 3.619104979507752e-10,
                      2.742092765095943e-13, -1.067200613381487e-15, 6.333980140159196e-19,
                      4.675391577876988,     505.1903283978535,      15.37334879108591,
                      -23.08738129086531,    358.7521218115685,      53.63424346389683]

        x = wavelength
        x1 = x if x < 650 else 650
        qe = 0
        for i in range(9):
            qe += par[i] * pow(x1, i);
        qe += par[9] * Gaus(x1, par[10], par[11])
        qe += par[12] * Gaus(x1, par[13], par[14])
        qe *= 0.01
        if(x > 650):
            qe *= (1 - (x - 650) / (675 - 650))
        if(qe < 0 or x < 200):
            qe = 0
        return qe
    
def CedarQE_R7400U_03(wavelength):
        par = [-58.41145755814,     1.450540667766,      -0.01561331198442,
                                    9.545010080831e-05,  -3.648461145542e-07, 9.047599515597e-10,
                                    -1.457151808585e-12, 1.471328774241e-15,  -8.46121819724e-19,
                                    2.11384701372e-22]

        x = wavelength
        if(x < 180):
            return 0
        if(x > 660):
            return 0
        qe = 0;
        for i in range(10):
            qe += par[i] * pow(x, i);
        if(qe < 0):
            qe = 0
        return qe



def Cedar_Eff_QE(wavelength):
    if (random.random() < 32/48):
        return CedarQE_R9880U_110(wavelength)
    else:
        return CedarQE_R7400U_03(wavelength)

    
def CedarWQuartzWindowAndFilterTransmittance(wavelength):
    x = wavelength
    f = 0
    if(x > 350):
        f = 0.905 + 0.00008 * (x - 350)
    elif(x > 300):
        f = 0.875 + 0.030 * (x - 300) / 50.0;
    elif(x > 280):
        f = 0.845 + 0.030 * (x - 280) / 20.0;
    elif(x > 270):
        f = 0.815 + 0.030 * (x - 270) / 10.0;
    elif(x > 260):
        f = 0.760 + 0.055 * (x - 260) / 10.0;
    elif(x > 250):
        f = 0.670 + 0.090 * (x - 250) / 10.0;
    elif(x > 240):
        f = 0.490 + 0.180 * (x - 240) / 10.0;
    else:
        f = 0.232 + 0.258 * (x - 230) / 10.0;
    if(f < 0.001):
        f = 0.001
    if(f > 0.999):
        f = 0.999
    return f

# %%
try:
    inFilek = uproot.open("3_8_large_dia.root")
    #inFilek = uproot.open("WH_3_85.root")
    #inFilek = uproot.open("WH_3_67.root")
    #inFilek = uproot.open("WN_1_7.root")
except OSError:
    exit(0)

# %%
    
fposition = inFilek['SlimMC;1']['Cedar/TDetectorVEvent/fHits/fHits.fPosition'].array()
fenergy = inFilek['SlimMC;1']['Cedar/TDetectorVEvent/fHits/fHits.fEnergy'].array()

fPDGCode = inFilek['SlimMC;1']['Generated/fKineParts/fKineParts.fPDGcode'].array()

fposition_x = list(fposition['fX'])
fposition_y = list(fposition['fY'])
fposition_z = list(fposition['fZ'])



x_e = []
y_e = []
z_e = []

r_e = []
w_e = []

r_e_K = []
w_e_K = []

r_e_pro = []
w_e_pro = []

r_e_pi = []
w_e_pi = []

for i in range(len(fposition_x)):
    if (i % 100 == 0):
        print(i)
    for t in range(len(fposition_x[i])):
        x = fposition_x[i][t]
        y = fposition_y[i][t]
        r = np.sqrt(x**2 + y**2)

        #print(r)

        w = ELConvert(fenergy[i][t])*1e-3
        if (random.random() > QuartzWindowCEDARHTransmittance(0,w)):
        	continue
     
        if(random.random() > Cedar_Eff_QE(w)):
            continue
        
        x_e.append(x)
        y_e.append(y)
        w_e.append(w)
        r_e.append(r)
        #print(fPDGCode[i][0])
        if fPDGCode[i][0] == 2212:
            #print(r_e_pro)
            w_e_pro.append(w)
            r_e_pro.append(r)
        elif fPDGCode[i][0] == 321:
            w_e_K.append(w)
            r_e_K.append(r)  
        elif fPDGCode[i][0] == 211:
            w_e_pi.append(w)
            r_e_pi.append(r) 
        else:
            pass
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
plt.rcParams['figure.constrained_layout.use'] = True
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

factor_1 = np.ones(len(r_e_pro)) / 46000
factor_2 = np.ones(len(r_e_K)) / 46000
factor_3 = np.ones(len(r_e_pi)) / 46000
#(mu, sigma) = norm.fit(r_e)
#print("mu = {} , sigma = {}".format(mu,sigma))
#n, bins, patches  = ax.hist(r_e, bins=100, range=(90,110))
ax.hist(r_e_pro, bins=100, range=(92,104.01), alpha=0.7,label="Proton",histtype='stepfilled', weights=factor_1)
ax.hist(r_e_K, bins=100, range=(92,104.01), alpha=0.7,label="Kaon",histtype='stepfilled', weights=factor_2)
ax.hist(r_e_pi, bins=100, range=(92,104.01), alpha=0.7,label="Pion",histtype='stepfilled', weights=factor_3)
ax.set_xlabel("Radius at diaphragm [mm]", fontsize=30)
ax.set_ylabel("Arbitrary scale" , fontsize=30)
#ax.set_title("Radius of Cherenkov Ring at the Diaphragm")
ax.axvline(x=101, ls="--", c="black", lw=5)
ax.axvline(x=99, ls="--", c="black", lw=5)
#dx = bins[1] - bins[0] 
#scale = dx * len(r_e)
#y = norm.pdf( bins, mu, sigma) * scale
#l = plt.plot(bins, y, 'r--', linewidth=2)
ax.set_xlim(92,104)
for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(2.5)

ax.tick_params(axis='both', which='major', pad=10, labelsize=30)

ax.tick_params(axis="both", which="major", length=20, width=2) 
ax.tick_params(axis="both", which="minor", length=10, width=2)
ax.set_ylim(0,1)
#plt.subplots_adjust(right=0.745)
plt.xticks(np.arange(92, 104.01, 2.0))
plt.legend(prop={'size': 30})
plt.gcf().set_size_inches((10,10))
plt.savefig("3_8_Radius_wQW_QE.pdf", format="pdf",bbox_inches='tight',dpi=200)

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(10, 10))

factor = np.ones(len(w_e)) / 640

h = ax1.hist2d((r_e), (w_e), bins=(200,200), cmin=1e-10, cmap='gist_rainbow', weights=factor, vmin=0, vmax=1)
ax1.set_ylabel("Wavelength [nm]", fontsize=30)
ax1.set_xlabel("Radius at diaphragm [mm]", fontsize=30)
#ax1.set_title("Radius of Cherenkov Ring at the Diaphragm vs Wavelength")
ax1.axvline(x=101, ls="--", c="black", lw=5)
ax1.axvline(x=99, ls="--", c="black", lw=5)
ax1.set_xlim(89.99,106)
ax1.set_ylim(199.999,700.001)
for axis in ['top', 'bottom', 'left', 'right']:
        ax1.spines[axis].set_linewidth(2.5)

ax1.tick_params(axis='both', which='major', pad=10, labelsize=30)

ax1.tick_params(axis="both", which="major", length=20, width=2) 
ax1.tick_params(axis="both", which="minor", length=10, width=2)
plt.xticks(np.arange(90, 106.01, 2.0))
shr = 1
cbar = fig1.colorbar(h[3], ax=ax1,pad=-0.03, shrink=shr, aspect=20*shr)
cbar.ax.set_ylim(0,1)
cbar.ax.tick_params(axis="both", which="major", length=20, width=2,labelsize=30) 
cbar.ax.tick_params(axis="both", which="minor", length=10, width=2)
for axis in ['top', 'bottom', 'left', 'right']:
        cbar.ax.spines[axis].set_linewidth(2.5)
        
plt.gcf().set_size_inches((10,10))
plt.savefig("3_8_WaveVSRadius_wQW_QE.pdf", format="pdf",bbox_inches='tight',dpi=200)
plt.show()

# %%
out_file = uproot.recreate("ring_width.root")

out_file["proton"] = {"proton": r_e_pro}
out_file["kaon"] = {"kaon": r_e_K} 
out_file["kaon"] = {"pion": r_e_pi}
out_file["WaveRadius"] = {"radius": r_e, "wavelength": w_e}
